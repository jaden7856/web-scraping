# %%
import requests

def translyric_savefile(trans_list):
    with open('data/yesterday_trans.txt','w',encoding='utf8') as file:
        file.writelines(trans_list)

#yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
def gettext_savelist():
    lyric_list = []
    with open('data/yesterday.txt','r',encoding='utf8') as file:
        contents = file.read()
        lyric_list = contents.split('\n')
    return lyric_list
    
def main():
    client_id = "6BrXjo2ExNSUtmO0zSyh"
    client_secret = "4ap8VA3I_I"
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

    #request header 값 선언
    req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    #yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
    lyric_list = gettext_savelist()
    print(len(lyric_list))
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0]    
    print(len(lyric_list))
    
    trans_list = []
    print('>> 번역시작')
    for req_lyric in lyric_list:
        print(req_lyric)
        #request form data 값 선언
        req_data = {
            "source":"en",
            "target":"ko",
            "text":req_lyric
        }
        #papago 서비스 요청, post() 함수 호출
        res = requests.post(url, data=req_data, headers=req_header)
        
        try:
            trans_lyric = res.json()['message']['result']['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
        
        trans_list.append(req_lyric+'\n')
        trans_list.append(trans_lyric+'\n')
        
    translyric_savefile(trans_list)
    print('>> 번역 종료')
    
main()

# %% [markdown]
# ## Module화 하여 숙제하기

# %%
import requests

def translyric_savefile(trans_list, title):
    with open('data/' + title + '_trans.txt','w',encoding='utf8') as file:
        file.writelines(trans_list)
        
def gettext_savelist(title):
    lyric_list = []
    with open('data/' + title + '.txt','r',encoding='utf8') as file:
        contents = file.read()
        lyric_list = contents.split('\n')
    return lyric_list

def papago(title, client_id, client_secret, source, target):
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

    #request header 값 선언
    req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    #yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
    lyric_list = gettext_savelist(title)
    print(len(lyric_list))
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0]    
    print(len(lyric_list))
    
    trans_list = []
    print('>> 번역시작')
    for req_lyric in lyric_list:
        print(req_lyric)
        #request form data 값 선언
        req_data = {
            "source":source,
            "target":target,
            "text":req_lyric
        }
        #papago 서비스 요청, post() 함수 호출
        res = requests.post(url, data=req_data, headers=req_header)
        
        try:
            trans_lyric = res.json()['message']['result']['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
        
        trans_list.append(req_lyric+'\n')
        trans_list.append(trans_lyric+'\n')
        
    translyric_savefile(trans_list, title)
    print('>> 번역 종료')

# %%
title = 'Lie'
client_id = "6BrXjo2ExNSUtmO0zSyh"
client_secret = "4ap8VA3I_I"
source = 'ko'
target = 'en'

papago(title, client_id, client_secret, source, target)
# Out:
# 51
# 45
# >> 번역시작
# 늦은밤 비가 내려와
# It's raining late at night.
# 널 데려와 젖은 기억 끝에 뒤척여 나
# Bring you in. I'm tossing and turning in my wet memory.
# 너 없 잘 살수 있다고
# I can live without you.
# 다짐해봐도 어쩔수 없다고
# I can't help it if I make up my mind.
# 못하는 술도 마시고
# I can't drink. I can't drink.
# 속타는 맘 밤새 채워봐도
# I've been up all night trying to keep my mind burning.
# 싫어 너 없는 하르는 길어 빌어
# No, Harr is long without you, wish.
# 제발 잊게 해달라고
# Please don't let me forget.
# 너 없는 내겐
# To me without you
# 웃음이 보이지 않아
# I can't see the smile.
# 눈물조차 고이지 않아
# I don't even cry.
# 더는 살고 싶지 않아
# I don't want to live anymore.
# ye 엿같애 열받게
# Yeah, damn it, you'm pissed.
# 니 생각에 돌아버릴것 같애
# I'm going crazy about you.
# 보고 싶은데 볼수가 없데
# I want to, but I can't.
# 모두 끝났데 I'll be right there
# I'll be right there.
# I'm so sorry but I love you
# I'm so sorry but I love you
# 다 거짓말 이야 몰랐어
# It's all a lie. I didn't know.
# 이제야 알았어 니가 필요해
# Now I know. I need you.
# I'm so sorry but I love you 날카로운 말
# I'm so sorry but I love you 날카로운 말
# 홧김에 나도 모르게 널 떠나보냈지만
# In a fit of anger, I let you leave without realizing it.
# I'm so sorry but I love you 다 거짓말
# I'm so sorry but I love you 다 거짓말
# I'm so sorry(sorry)but I love you
# I'm so sorry(sorry)but I love you
# I'm so sorry but I love you
# I'm so sorry but I love you
# 나를 떠나 천천히 잊어줄래
# Leave me and forget me slowly.
# 내가 아파할수 있게
# So I can be hurt.
# 그댈 위해서 불러왔던
# I've been calling for you.
# 내 모든걸 다 바친노래
# A song that I've dedicated my whole life to.
# 사람들은 모르겠죠
# People don't know.
# 나 혼자 그 아무도 아무도 몰래
# I'm the only one who knows how to sneak up on anyone.
# 그래 내가 했던말은 거짓말
# Yeah, what I said was a lie.
# 홀로 남겨진 외톨이
# Loner Left Alone
# 그속에 헤메는 내 꼴이
# The way I'm swimming in it.
# 주머니속에 꼬깃 꼬깃 접어둔
# folded in one's pocket
# 이별을 향한 쪽지
# a note for parting
# 넌 어딨나요 널부르는 습관도
# Where are you? The habit of calling you.
# 난 달라질래 이젠 다 웃어넘길게
# I'm gonna make a difference. I'm gonna laugh it off now.
# oh oh ohoh...
# oh oh ohoh...
# oh oh oh..
# oh oh oh..
# 이것밖에 안되는 나 라서
# This is the only country I've ever had.
# trop that bit
# trop that bit
# 아직도 너를 못잊어
# I still can't forget you.
# 아니 평생을 가도 죽어서까지도 ye
# No, no, no, no, no, no, no, no, no.
# 내가 준 상처 아물었는지
# Did the wound I gave you heal?
# 미안해 아무것도 해준게 없는 나라서
# I'm sorry I didn't do anything for you.
# >> 번역 종료
